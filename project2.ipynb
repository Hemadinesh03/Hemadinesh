# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('weather.csv')
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 122571    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 122572      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 122573        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 122574       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 122575     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df[['temperature_celsius']]=(df['temperature_celsius'].mean())
df
df['sunset']=pd.to_datetime(df['sunset'])
df['sunrise']=pd.to_datetime(df['sunrise'])
print('average daily sunset time:', df['sunset'].mean())
print('average daily sunrise time:', df['sunrise'].mean())
df
# Out:
# average daily sunset time: 2026-02-13 18:30:31.147369728
# average daily sunrise time: 2026-02-13 06:21:51.125016064
# C:\Users\bhema\AppData\Local\Temp\ipykernel_5236\1854323057.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['sunrise']=pd.to_datetime(df['sunrise'])
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# ...

# %%
df.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %%
df.shape
# Out:
# (122576, 41)

# %%
print(df['temperature_celsius'].min(),df['temperature_celsius'].max())
print(df['temperature_celsius'].nunique())
# Out:
# 21.702573913327242 21.702573913327242
# 1

# %%
print(df['last_updated'].max(),df['last_updated'].min())
# Out:
# 2026-02-06 19:45 2024-05-16 01:45

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15            21.702574
# 1          1715849100  2024-05-16 10:45            21.702574
# 2          1715849100  2024-05-16 09:45            21.702574
# 3          1715849100  2024-05-16 10:45            21.702574
# 4          1715849100  2024-05-16 09:45            21.702574
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.tail()
# Out:
#           country location_name  latitude  longitude         timezone  \
# 122571  Venezuela       Caracas   10.5000   -66.9167  America/Caracas
# 122572    Vietnam         Hanoi   21.0333   105.8500     Asia/Bangkok
# 122573      Yemen         Sanaa   15.3547    44.2067        Asia/Aden
# 122574     Zambia        Lusaka  -15.4167    28.2833    Africa/Lusaka
# 122575   Zimbabwe        Harare  -17.8178    31.0447    Africa/Harare
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# 122571          1770360300  2026-02-06 02:45            21.702574
# 122572          1770360300  2026-02-06 13:45            21.702574
# 122573          1770360300  2026-02-06 09:45            21.702574
# 122574          1770360300  2026-02-06 08:45            21.702574
# 122575          1770360300  2026-02-06 08:45            21.702574
#
#         temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 122571                    61.5          Clear  ...               9.55
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122576 entries, 0 to 122575
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       122576 non-null  object
#  1   location_name                 122576 non-null  object
#  2   latitude                      122576 non-null  float64
#  3   longitude                     122576 non-null  float64
#  4   timezone                      122576 non-null  object
#  5   last_updated_epoch            122576 non-null  int64
#  6   last_updated                  122576 non-null  object
#  7   temperature_celsius           122576 non-null  float64
#  8   temperature_fahrenheit        122576 non-null  float64
#  9   condition_text                122576 non-null  object
#  10  wind_mph                      122576 non-null  float64
#  11  wind_kph                      122576 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
cols = ["pressure_in","precip_mm","precip_in","humidity","cloud",
    "feels_like_celsius","feels_like_fahrenheit","visibility_km","visibility_miles","uv_index",
    "gust_mph","gust_kph",
    "air_quality_Carbon_Monoxide","air_quality_Ozone","air_quality_Nitrogen_dioxide",
    "air_quality_Sulphur_dioxide","air_quality_PM2.5","air_quality_PM10",
    "air_quality_us-epa-index","air_quality_gb-defra-index",
    "sunrise","sunset","moonrise","moonset","moon_phase","moon_illumination"]
df[cols] = df[cols].fillna(0)
df[cols]
# Out:
#         pressure_in  precip_mm  precip_in  humidity  cloud  \
# 0             29.89        0.0       0.00        24     30
# 1             29.88        0.1       0.00        94     75
# 2             29.85        0.0       0.00        29      0
# 3             29.75        0.3       0.01        61    100
# 4             29.85        0.0       0.00        89     50
# ...             ...        ...        ...       ...    ...
# 122571        29.97        0.0       0.00        71      6
# 122572        29.91        0.0       0.00        74     75
# 122573        30.12        0.0       0.00        30      2
# 122574        29.98        0.0       0.00        77     26
# 122575        30.03        0.0       0.00        73     17
#
#         feels_like_celsius  feels_like_fahrenheit  visibility_km  \
# 0                     25.3                   77.5           10.0
# 1                     19.0                   66.2           10.0
# ...

# %%
df.describe()
# Out:
#             latitude      longitude  last_updated_epoch  temperature_celsius  \
# count  122576.000000  122576.000000        1.225760e+05         1.225760e+05
# mean       19.191038      21.996451        1.743124e+09         2.170257e+01
# std        24.427963      65.792124        1.573369e+07         5.588441e-12
# min       -41.300000    -175.200000        1.715849e+09         2.170257e+01
# 25%         3.750000      -6.836100        1.729502e+09         2.170257e+01
# 50%        17.250000      23.316700        1.743155e+09         2.170257e+01
# 75%        40.400000      50.580000        1.756714e+09         2.170257e+01
# max        64.150000     179.220000        1.770360e+09         2.170257e+01
#
#        temperature_fahrenheit       wind_mph       wind_kph    wind_degree  \
# count           122576.000000  122576.000000  122576.000000  122576.000000
# mean                71.066384       8.078715      13.004998     169.303012
# ...

# %%
df['last_updated']=pd.to_datetime(df['last_updated'])
df['last_updated']
# Out:
# 0        2024-05-16 13:15:00
# 1        2024-05-16 10:45:00
# 2        2024-05-16 09:45:00
# 3        2024-05-16 10:45:00
# 4        2024-05-16 09:45:00
#                  ...
# 122571   2026-02-06 02:45:00
# 122572   2026-02-06 13:45:00
# 122573   2026-02-06 09:45:00
# 122574   2026-02-06 08:45:00
# 122575   2026-02-06 08:45:00
# Name: last_updated, Length: 122576, dtype: datetime64[ns]

# %%
df=df.drop_duplicates()

# %%
import seaborn as sns
sns.boxplot(df['temperature_celsius'])
# Out:
# <Axes: ylabel='temperature_celsius'>

# %%
humidity=df[(df['humidity']>=0 ) & (df['humidity'] < 100)]
humidity
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 122571    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 122572      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 122573        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 122574       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 122575     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
sns.boxplot(df['humidity'])
# Out:
# <Axes: ylabel='humidity'>
